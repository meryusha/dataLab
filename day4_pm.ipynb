# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
flights = sns.load_dataset('flights')
tips = sns.load_dataset('tips')
flights.head(5)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), cmap ='coolwarm', annot= True)

# %%
pv_flights = flights.pivot_table(values= 'passengers', index = 'month', columns = 'year')

# %%
sns.heatmap(pv_flights, cmap = 'magma')

# %%
sns.clustermap(pv_flights)

# %%
titanic = sns.load_dataset('titanic')
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#2
sns.lmplot(x = 'age', y = 'fare', data = titanic)
#plt.xlabel("fare")
#plt.ylabel('age')

# %%
#3
sns.distplot(titanic['fare'])
# Out:
# /home/student/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#4
sns.boxplot(x = 'class', y = 'age', data = titanic)

# %%
#5
#4
sns.swarmplot(x = 'class', y = 'age', data = titanic)

# %%
#6
sns.countplot(titanic['sex'])

# %%
#7
sns.heatmap(titanic.corr(), cmap ='coolwarm', annot= True)

# %%
g = sns.FacetGrid(titanic, col = 'sex')
g = sns.FacetGrid(titanic, col = 'sex')
g = g.map(plt.hist, 'age')
#titanic.head()
#titanic.head()

# %%
g = sns.FacetGrid(titanic, col = 'alive')
g = g.map(plt.hist, 'age')
#titanic.head()

# %%
countplot = sns.countplot( titanic['alone'])
countplot.set_xticklabels(('With Family', 'Alone'))
countplot.set(xlabel = "Family")
# Out:
# [Text(0.5,0,'Family')]

# %%
countplot = sns.barplot(x = 'alone', y = 'alive', data = titanic)

countplot.set_xticklabels(('With Family', 'Alone'))
countplot.set(xlabel = "Family")
# Out:
# [Text(0.5,0,'Family')]
