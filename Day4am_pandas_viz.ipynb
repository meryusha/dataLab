# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("./viz/df1",index_col=0)
df2 = pd.read_csv("./viz/df2")

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1["A"].hist()

# %%
df1["A"].hist(bins=30)

# %%
df1[(df1["A"]>-1.5) & (df1["A"]<1.5)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
# A    888 non-null float64
# B    888 non-null float64
# C    888 non-null float64
# D    888 non-null float64
# dtypes: float64(4)
# memory usage: 34.7+ KB

# %%
df1[(df1["A"]>-1.5) & (df1["A"]<1.5)].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f169bac0128>,
# ...
#       dtype=object)

# %%
plt.style.use("ggplot")

# %%
df1["A"].hist()

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.line(y="B", figsize=(12,3), lw=0.5)

# %%
df1.plot.scatter(x="A",y="B")

# %%
df1.plot.scatter(x="A",y="B",c="C",cmap="coolwarm")

# %%
df1.plot.scatter(x="A",y="B",s=df1["C"]*100,c="D",cmap="summer")
# Out:
# /home/student/anaconda3/lib/python3.6/site-packages/matplotlib/collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df2.loc[0] = [3,4,5,6]

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=["a","b"])

# %%
df.plot.hexbin(x="a",y="b",gridsize=25,cmap="Oranges")

# %%
df2["a"].hist(bins=100)
df2["a"].plot.kde()

# %%
df2.plot.kde()
