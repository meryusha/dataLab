# %%
import numpy as np
import pandas as pd
# Out:
#                                         0               1               2  \
# age                                    41              23              46
# sex                                     F               F               M
# on_thyroxine                            f               f               f
# query_on_thyroxine                      f               f               f
# on_antithyroid_medication               f               f               f
# sick                                    f               f               f
# pregnant                                f               f               f
# thyroid_surgery                         f               f               f
# I131_treatment                          f               f               f
# query_hypothyroid                       f               f               f
# query_hyperthyroid                      f               f               f
# lithium                                 f               f               f
# goitre                                  f               f               f
# tumor                                   f               f               f
# hypopituitary                           f               f               f
# psych                                   f               f               f
# TSH_measured                            t               t               t
# TSH                                   1.3             4.1            0.98
# T3_measured                             t               t               f
# TT4_measured                          2.5               2             NaN
# TT4                                     t               t               t
# T4U_measured                          125             102             109
# T4U                                     t               f               t
# FTI measured                         1.14             NaN            0.91
# FTI                                     t               f               t
# TBG_measured                          109             NaN             120
# TBG                                     f               f               f
# temp?                                 NaN             NaN             NaN
# referral_source                      SVHC           other           other
# target                     negative.|3733  negative.|1442  negative.|2965
#
#                                        3               4
# age                                   70              70
# sex                                    F               F
# on_thyroxine                           t               f
# query_on_thyroxine                     f               f
# on_antithyroid_medication              f               f
# sick                                   f               f
# pregnant                               f               f
# thyroid_surgery                        f               f
# I131_treatment                         f               f
# query_hypothyroid                      f               f
# query_hyperthyroid                     f               f
# lithium                                f               f
# goitre                                 f               f
# tumor                                  f               f
# hypopituitary                          f               f
# psych                                  f               f
# TSH_measured                           t               t
# TSH                                 0.16            0.72
# T3_measured                            t               t
# TT4_measured                         1.9             1.2
# TT4                                    t               t
# T4U_measured                         175              61
# T4U                                    f               t
# FTI measured                         NaN            0.87
# FTI                                    f               t
# TBG_measured                         NaN              70
# TBG                                    f               f
# temp?                                NaN             NaN
# referral_source                    other             SVI
# target                     negative.|806  negative.|2807

# %% [markdown]
# # Working with allbp

# %%
names_allbp =['age','sex','on_thyroxine','query_on_thyroxine','on_antithyroid_medication','sick', 'pregnant', 'thyroid_surgery', 'I131_treatment', 'query_hypothyroid', 'query_hyperthyroid','lithium', 'goitre', 'tumor', 'hypopituitary', 'psych','TSH_measured', 'TSH', 'T3_measured','TT4_measured','TT4', 'T4U_measured', 'T4U', 'FTI measured', 'FTI', 'TBG_measured','TBG','temp?', 'referral_source', 'target']
data_allbp = pd.read_csv('allbp.data', names=names_allbp, index_col=False, na_values='?')
data_allbp.info()
# data_allbp[data_allbp == pd.nan].count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 30 columns):
# age                          2799 non-null float64
# sex                          2690 non-null object
# on_thyroxine                 2800 non-null object
# query_on_thyroxine           2800 non-null object
# on_antithyroid_medication    2800 non-null object
# sick                         2800 non-null object
# pregnant                     2800 non-null object
# thyroid_surgery              2800 non-null object
# I131_treatment               2800 non-null object
# query_hypothyroid            2800 non-null object
# query_hyperthyroid           2800 non-null object
# lithium                      2800 non-null object
# goitre                       2800 non-null object
# tumor                        2800 non-null object
# hypopituitary                2800 non-null object
# psych                        2800 non-null object
# TSH_measured                 2800 non-null object
# TSH                          2516 non-null float64
# T3_measured                  2800 non-null object
# TT4_measured                 2215 non-null float64
# TT4                          2800 non-null object
# T4U_measured                 2616 non-null float64
# T4U                          2800 non-null object
# FTI measured                 2503 non-null float64
# FTI                          2800 non-null object
# TBG_measured                 2505 non-null float64
# TBG                          2800 non-null object
# temp?                        0 non-null float64
# referral_source              2800 non-null object
# target                       2800 non-null object
# dtypes: float64(7), object(23)
# memory usage: 656.3+ KB

# %%
data_allbp.drop('temp?', axis = 1, inplace = True)
data_allbp.head().T
# Out:
#                                         0               1               2  \
# age                                    41              23              46
# sex                                     F               F               M
# on_thyroxine                            f               f               f
# query_on_thyroxine                      f               f               f
# on_antithyroid_medication               f               f               f
# sick                                    f               f               f
# pregnant                                f               f               f
# thyroid_surgery                         f               f               f
# I131_treatment                          f               f               f
# query_hypothyroid                       f               f               f
# query_hyperthyroid                      f               f               f
# lithium                                 f               f               f
# goitre                                  f               f               f
# tumor                                   f               f               f
# hypopituitary                           f               f               f
# psych                                   f               f               f
# TSH_measured                            t               t               t
# TSH                                   1.3             4.1            0.98
# T3_measured                             t               t               f
# TT4_measured                          2.5               2             NaN
# TT4                                     t               t               t
# T4U_measured                          125             102             109
# T4U                                     t               f               t
# FTI measured                         1.14             NaN            0.91
# FTI                                     t               f               t
# TBG_measured                          109             NaN             120
# TBG                                     f               f               f
# referral_source                      SVHC           other           other
# target                     negative.|3733  negative.|1442  negative.|2965
#
#                                        3               4
# age                                   70              70
# sex                                    F               F
# on_thyroxine                           t               f
# query_on_thyroxine                     f               f
# on_antithyroid_medication              f               f
# sick                                   f               f
# pregnant                               f               f
# thyroid_surgery                        f               f
# I131_treatment                         f               f
# query_hypothyroid                      f               f
# query_hyperthyroid                     f               f
# lithium                                f               f
# goitre                                 f               f
# tumor                                  f               f
# hypopituitary                          f               f
# psych                                  f               f
# TSH_measured                           t               t
# TSH                                 0.16            0.72
# T3_measured                            t               t
# TT4_measured                         1.9             1.2
# TT4                                    t               t
# T4U_measured                         175              61
# T4U                                    f               t
# FTI measured                         NaN            0.87
# FTI                                    f               t
# TBG_measured                         NaN              70
# TBG                                    f               f
# referral_source                    other             SVI
# target                     negative.|806  negative.|2807

# %%
data_allbp['neg/pos'] = data_allbp['target'].apply( lambda x: x.split('.|')[0])
data_allbp['neg/pos'].value_counts()
# Out:
# negative                     2667
# increased binding protein     124
# decreased binding protein       9
# Name: neg/pos, dtype: int64

# %%
data_allbp
# Out:
#        age  sex on_thyroxine query_on_thyroxine on_antithyroid_medication  \
# 0     41.0    F            f                  f                         f
# 1     23.0    F            f                  f                         f
# 2     46.0    M            f                  f                         f
# 3     70.0    F            t                  f                         f
# 4     70.0    F            f                  f                         f
# 5     18.0    F            t                  f                         f
# 6     59.0    F            f                  f                         f
# 7     80.0    F            f                  f                         f
# 8     66.0    F            f                  f                         f
# 9     68.0    M            f                  f                         f
# 10    84.0    F            f                  f                         f
# 11    67.0    F            t                  f                         f
# 12    71.0    F            f                  f                         f
# 13    59.0    F            f                  f                         f
# 14    28.0    M            f                  f                         f
# 15    65.0    F            f                  f                         f
# 16    42.0  NaN            f                  f                         f
# 17    63.0    F            f                  f                         f
# 18    80.0    F            f                  f                         f
# 19    28.0    M            f                  f                         f
# 20    51.0    F            t                  f                         f
# 21    46.0    M            f                  f                         f
# 22    81.0    M            f                  f                         f
# 23    54.0    F            f                  f                         f
# 24    55.0    M            f                  f                         f
# 25    63.0    F            f                  f                         f
# 26    60.0    M            t                  f                         f
# 27    25.0    F            f                  f                         f
# 28    73.0    F            f                  f                         f
# 29    67.0    M            f                  f                         f
# ...    ...  ...          ...                ...                       ...
# 2770  31.0    F            f                  f                         f
# 2771  71.0    F            f                  f                         f
# 2772  25.0    F            f                  f                         f
# 2773  84.0    M            f                  f                         f
# 2774  82.0    M            f                  f                         f
# 2775  55.0    M            f                  f                         f
# 2776  79.0    M            f                  f                         f
# 2777  54.0  NaN            f                  f                         f
# 2778  52.0    F            f                  f                         f
# 2779  27.0  NaN            f                  f                         f
# 2780  49.0    F            f                  f                         f
# 2781  72.0    F            f                  f                         f
# 2782  50.0    F            f                  f                         f
# 2783  82.0    F            f                  f                         f
# 2784  27.0    F            f                  f                         f
# 2785  57.0    M            f                  f                         f
# 2786  73.0  NaN            f                  f                         f
# 2787  58.0    M            f                  f                         f
# 2788  70.0    M            f                  f                         f
# 2789  54.0    F            f                  f                         f
# 2790  67.0    M            f                  f                         f
# 2791  68.0    F            f                  f                         f
# 2792  63.0  NaN            f                  f                         f
# 2793  82.0    F            f                  f                         f
# 2794  25.0    F            f                  f                         f
# 2795  70.0    M            f                  f                         f
# 2796  73.0    M            f                  t                         f
# 2797  75.0    M            f                  f                         f
# 2798  60.0    F            f                  f                         f
# 2799  81.0    F            f                  f                         f
#
#      sick pregnant thyroid_surgery I131_treatment query_hypothyroid  \
# 0       f        f               f              f                 f
# 1       f        f               f              f                 f
# 2       f        f               f              f                 f
# 3       f        f               f              f                 f
# 4       f        f               f              f                 f
# 5       f        f               f              f                 f
# 6       f        f               f              f                 f
# 7       f        f               f              f                 f
# 8       f        f               f              f                 f
# 9       f        f               f              f                 f
# 10      f        f               f              f                 f
# 11      f        f               f              f                 f
# 12      t        f               f              f                 f
# 13      f        f               f              f                 f
# 14      f        f               f              f                 f
# 15      f        f               f              f                 t
# 16      f        f               f              f                 f
# 17      f        f               f              f                 f
# 18      f        f               f              f                 f
# 19      f        f               f              f                 f
# 20      f        f               f              f                 f
# 21      f        f               f              f                 f
# 22      f        f               f              f                 f
# 23      f        f               f              f                 f
# 24      f        f               f              f                 f
# 25      f        f               f              f                 f
# 26      f        f               f              f                 f
# 27      f        f               f              f                 f
# 28      f        f               f              f                 f
# 29      f        f               f              f                 f
# ...   ...      ...             ...            ...               ...
# 2770    f        f               f              f                 f
# 2771    f        f               f              f                 f
# 2772    f        f               f              f                 f
# 2773    f        f               f              f                 f
# 2774    f        f               f              f                 f
# 2775    f        f               f              f                 f
# 2776    f        f               f              f                 f
# 2777    f        f               f              f                 f
# 2778    f        f               t              f                 f
# 2779    f        f               f              f                 f
# 2780    f        f               f              f                 f
# 2781    f        f               f              f                 f
# 2782    f        f               f              f                 t
# 2783    f        f               f              f                 f
# 2784    f        f               f              f                 f
# 2785    t        f               f              f                 f
# 2786    f        f               f              f                 f
# 2787    f        f               f              f                 f
# 2788    f        f               f              f                 f
# 2789    f        f               f              f                 f
# 2790    f        f               f              f                 t
# 2791    f        f               f              f                 f
# 2792    f        f               f              f                 f
# 2793    f        f               f              f                 f
# 2794    f        f               f              f                 f
# 2795    f        f               f              f                 f
# 2796    f        f               f              f                 f
# 2797    f        f               f              f                 f
# 2798    f        f               f              f                 f
# 2799    f        f               f              f                 f
#
#                 ...             TT4 T4U_measured T4U FTI measured FTI  \
# 0               ...               t        125.0   t         1.14   t
# 1               ...               t        102.0   f          NaN   f
# 2               ...               t        109.0   t         0.91   t
# 3               ...               t        175.0   f          NaN   f
# 4               ...               t         61.0   t         0.87   t
# 5               ...               t        183.0   t         1.30   t
# 6               ...               t         72.0   t         0.92   t
# 7               ...               t         80.0   t         0.70   t
# 8               ...               t        123.0   t         0.93   t
# 9               ...               t         83.0   t         0.89   t
# 10              ...               t        115.0   t         0.95   t
# 11              ...               t        152.0   t         0.99   t
# 12              ...               t        171.0   t         1.13   t
# 13              ...               t         97.0   t         0.91   t
# 14              ...               t        109.0   t         0.91   t
# 15              ...               t         99.0   t         1.14   t
# 16              ...               t         70.0   t         0.86   t
# 17              ...               t        117.0   t         0.96   t
# 18              ...               t         99.0   t         0.95   t
# 19              ...               t        121.0   t         0.94   t
# 20              ...               t        130.0   t         0.86   t
# 21              ...               t        108.0   t         0.91   t
# 22              ...               t        102.0   t         0.96   t
# 23              ...               t        104.0   t         0.90   t
# 24              ...               t        134.0   t         1.02   t
# 25              ...               t        199.0   t         1.05   t
# 26              ...               t         57.0   t         0.62   t
# 27              ...               t        129.0   f          NaN   f
# 28              ...               t        113.0   t         1.06   t
# 29              ...               t         97.0   t         0.95   t
# ...             ...              ..          ...  ..          ...  ..
# 2770            ...               t        196.0   t         0.94   t
# 2771            ...               t         96.0   t         1.05   t
# 2772            ...               t         21.0   t         1.10   t
# 2773            ...               t         82.0   t         0.74   t
# 2774            ...               t         68.0   t         0.77   t
# 2775            ...               f          NaN   f          NaN   f
# 2776            ...               t        116.0   t         0.85   t
# 2777            ...               t        127.0   t         1.24   t
# 2778            ...               t         80.0   t         0.82   t
# 2779            ...               t        121.0   t         1.23   t
# 2780            ...               f          NaN   f          NaN   f
# 2781            ...               t         87.0   t         0.93   t
# 2782            ...               t         98.0   t         0.80   t
# 2783            ...               t        125.0   t         0.84   t
# 2784            ...               t        104.0   f          NaN   f
# 2785            ...               t         73.0   t         0.97   t
# 2786            ...               t        173.0   t         1.00   t
# 2787            ...               f          NaN   f          NaN   f
# 2788            ...               t         70.0   t         0.77   t
# 2789            ...               f          NaN   f          NaN   f
# 2790            ...               t         83.0   t         0.96   t
# 2791            ...               t        103.0   t         1.01   t
# 2792            ...               f          NaN   f          NaN   f
# 2793            ...               t         74.0   t         0.52   t
# 2794            ...               t        167.0   t         1.21   t
# 2795            ...               t        155.0   t         1.05   t
# 2796            ...               t         63.0   t         0.88   t
# 2797            ...               t        147.0   t         0.80   t
# 2798            ...               t        100.0   t         0.83   t
# 2799            ...               t        114.0   t         0.99   t
#
#      TBG_measured TBG  referral_source                           target  \
# 0           109.0   f             SVHC                   negative.|3733
# 1             NaN   f            other                   negative.|1442
# 2           120.0   f            other                   negative.|2965
# 3             NaN   f            other                    negative.|806
# 4            70.0   f              SVI                   negative.|2807
# 5           141.0   f            other                   negative.|3434
# 6            78.0   f            other                   negative.|1595
# 7           115.0   f              SVI                   negative.|1367
# 8           132.0   f              SVI                   negative.|1787
# 9            93.0   f              SVI                   negative.|2534
# 10          121.0   f              SVI                   negative.|1485
# 11          153.0   f            other                   negative.|3448
# 12          151.0   f            other                   negative.|1027
# 13          107.0   f              SVI                   negative.|3331
# 14          119.0   f             SVHC                   negative.|2043
# 15           87.0   f            other                   negative.|3169
# 16           81.0   f            other                   negative.|2755
# 17          121.0   f              SVI                   negative.|1010
# 18          104.0   f              SVI                    negative.|803
# 19          130.0   f             SVHC                   negative.|2297
# 20          151.0   f            other                   negative.|3564
# 21          119.0   f            other                    negative.|152
# 22          106.0   f              SVI                    negative.|936
# 23          116.0   f            other                    negative.|716
# 24          131.0   f              SVI                   negative.|1933
# 25          190.0   f            other                   negative.|3445
# 26           92.0   f            other                   negative.|3724
# 27            NaN   f            other   increased binding protein.|185
# 28          106.0   f              SVI                   negative.|1966
# 29          102.0   f            other                    negative.|466
# ...           ...  ..              ...                              ...
# 2770        209.0   f            other                    negative.|415
# 2771         92.0   f              SVI                   negative.|1661
# 2772         19.0   f            other                   negative.|3047
# 2773        110.0   f              SVI                   negative.|2787
# 2774         88.0   f              SVI                    negative.|991
# 2775          NaN   f            other                   negative.|3702
# 2776        137.0   f              SVI                    negative.|932
# 2777        102.0   f              SVI                   negative.|2825
# 2778         98.0   f            other                    negative.|691
# 2779         98.0   f            other                   negative.|2971
# 2780          NaN   f            other                    negative.|454
# 2781         93.0   f            other                   negative.|3681
# 2782        122.0   f              SVI                   negative.|1691
# 2783        149.0   f            other                   negative.|2985
# 2784          NaN   f            other                     negative.|66
# 2785         75.0   f              SVI                    negative.|182
# 2786        173.0   f            other                   negative.|2431
# 2787          NaN   f            other                   negative.|3214
# 2788         91.0   f              SVI                   negative.|2979
# 2789          NaN   f            other                    negative.|451
# 2790         87.0   f              SVI                     negative.|60
# 2791        102.0   f              SVI                   negative.|3622
# 2792          NaN   f            other                   negative.|2383
# 2793        143.0   f            other                   negative.|1084
# 2794        137.0   f            other  increased binding protein.|2245
# 2795        148.0   f              SVI                   negative.|3689
# 2796         72.0   f            other                   negative.|3652
# 2797        183.0   f            other                   negative.|1287
# 2798        121.0   f            other                   negative.|3496
# 2799        115.0   f              SVI                    negative.|724
#
#                         neg/pos
# 0                      negative
# 1                      negative
# 2                      negative
# 3                      negative
# 4                      negative
# 5                      negative
# 6                      negative
# 7                      negative
# 8                      negative
# 9                      negative
# 10                     negative
# 11                     negative
# 12                     negative
# 13                     negative
# 14                     negative
# 15                     negative
# 16                     negative
# 17                     negative
# 18                     negative
# 19                     negative
# 20                     negative
# 21                     negative
# 22                     negative
# 23                     negative
# 24                     negative
# 25                     negative
# 26                     negative
# 27    increased binding protein
# 28                     negative
# 29                     negative
# ...                         ...
# 2770                   negative
# 2771                   negative
# 2772                   negative
# 2773                   negative
# 2774                   negative
# 2775                   negative
# 2776                   negative
# 2777                   negative
# 2778                   negative
# 2779                   negative
# 2780                   negative
# 2781                   negative
# 2782                   negative
# 2783                   negative
# 2784                   negative
# 2785                   negative
# 2786                   negative
# 2787                   negative
# 2788                   negative
# 2789                   negative
# 2790                   negative
# 2791                   negative
# 2792                   negative
# 2793                   negative
# 2794  increased binding protein
# 2795                   negative
# 2796                   negative
# 2797                   negative
# 2798                   negative
# 2799                   negative
#
# [2800 rows x 30 columns]

# %% [markdown]
# # Working with allhyper

# %%
names_allhyper =['age','sex','on_thyroxine','query_on_thyroxine','on_antithyroid_medication','sick', 'pregnant', 'thyroid_surgery', 'I131_treatment', 'query_hypothyroid', 'query_hyperthyroid','lithium', 'goitre', 'tumor', 'hypopituitary', 'psych','TSH_measured', 'TSH', 'T3_measured','TT4_measured','TT4', 'T4U_measured', 'T4U', 'FTI measured', 'FTI', 'TBG_measured','TBG','temp?', 'referral_source', 'target']
data_allhyper = pd.read_csv('allhyper.data', names=names_allhyper, index_col=False, na_values='?')
data_allhyper.head()
# Out:
#     age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  41.0   F            f                  f                         f    f
# 1  23.0   F            f                  f                         f    f
# 2  46.0   M            f                  f                         f    f
# 3  70.0   F            t                  f                         f    f
# 4  70.0   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid       ...        \
# 0        f               f              f                 f       ...
# 1        f               f              f                 f       ...
# 2        f               f              f                 f       ...
# 3        f               f              f                 f       ...
# 4        f               f              f                 f       ...
#
#   TT4 T4U_measured T4U FTI measured FTI TBG_measured TBG  temp?  \
# 0   t        125.0   t         1.14   t        109.0   f    NaN
# 1   t        102.0   f          NaN   f          NaN   f    NaN
# 2   t        109.0   t         0.91   t        120.0   f    NaN
# 3   t        175.0   f          NaN   f          NaN   f    NaN
# 4   t         61.0   t         0.87   t         70.0   f    NaN
#
#   referral_source          target
# 0            SVHC  negative.|3733
# 1           other  negative.|1442
# 2           other  negative.|2965
# 3           other   negative.|806
# 4             SVI  negative.|2807
#
# [5 rows x 30 columns]

# %% [markdown]
# # New Thyroid

# %%
names_new_thyroid = ['class', 'T3', 'total_ser(iso)', 'total_ser(rad)', 'TSH', 'max_diff_TSH']

data_new_thyroid = pd.read_csv('new-thyroid.data', names = names_new_thyroid, index_col = False)
# data_new_thyroid = pd.read_csv('new-thyroid.data',  index_col = False)
data_new_thyroid.head()
# Out:
#    class   T3  total_ser(iso)  total_ser(rad)  TSH  max_diff_TSH
# 0      1  107            10.1             2.2  0.9           2.7
# 1      1  113             9.9             3.1  2.0           5.9
# 2      1  127            12.9             2.4  1.4           0.6
# 3      1  109             5.3             1.6  1.4           1.5
# 4      1  105             7.3             1.5  1.5          -0.1

# %% [markdown]
# # Working with thyroid0387
